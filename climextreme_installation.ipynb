# %%
import climextremes
# Out:
# R[write to console]: Error in library(climextRemes) :
#   there is no package called ‘climextRemes’
#
# R[write to console]: Loading required package: usethis
#
# R[write to console]: Error: package or namespace load failed for ‘usethis’ in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]):
#  namespace ‘rlang’ 1.0.2 is already loaded, but >= 1.0.5 is required
#
# R[write to console]: Error: package ‘usethis’ could not be loaded
#
# R[write to console]: In addition:
# R[write to console]: Warning message:
#
# R[write to console]: package ‘usethis’ was built under R version 4.1.3
# Attempting installation of R climextRemes package and its dependencies (this may take a few minutes) ...
# ...
