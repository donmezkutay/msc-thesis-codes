# %%
import climextremes
# Out:
# R[write to console]: Error in library(climextRemes) :
#   there is no package called ‘climextRemes’
#
# R[write to console]: Error in library(devtools) : there is no package called ‘devtools’
# Attempting installation of R climextRemes package and its dependencies (this may take a few minutes) ...
# R[write to console]: also installing the dependencies ‘httpuv’, ‘systemfonts’, ‘textshaping’, ‘shiny’, ‘bslib’, ‘ragg’, ‘rmarkdown’, ‘miniUI’, ‘pkgdown’
#
#
# R[write to console]: trying URL 'https://cran.us.r-project.org/src/contrib/httpuv_1.6.6.tar.gz'
#
# R[write to console]: Content type 'application/octet-stream'
# R[write to console]:  length 1875264 bytes (1.8 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
import climextremes
# Out:
# R[write to console]: Error in library(climextRemes) :
#   there is no package called ‘climextRemes’
#
# R[write to console]: Error in library(devtools) : there is no package called ‘devtools’
# Attempting installation of R climextRemes package and its dependencies (this may take a few minutes) ...
# R[write to console]: also installing the dependencies ‘systemfonts’, ‘textshaping’, ‘ragg’, ‘pkgdown’
#
#
# R[write to console]: trying URL 'https://cran.us.r-project.org/src/contrib/systemfonts_1.0.4.tar.gz'
#
# R[write to console]: Content type 'application/octet-stream'
# R[write to console]:  length 81757 bytes (79 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
import climextremes
# Out:
# R[write to console]: Error in library(climextRemes) :
#   there is no package called ‘climextRemes’
#
# R[write to console]: Error in library(devtools) : there is no package called ‘devtools’
# Attempting installation of R climextRemes package and its dependencies (this may take a few minutes) ...
# R[write to console]: also installing the dependencies ‘systemfonts’, ‘textshaping’, ‘ragg’, ‘pkgdown’
#
#
# R[write to console]: trying URL 'https://cran.us.r-project.org/src/contrib/systemfonts_1.0.4.tar.gz'
#
# R[write to console]: Content type 'application/octet-stream'
# R[write to console]:  length 81757 bytes (79 KB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...
